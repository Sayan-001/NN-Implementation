# %% [markdown]
# ### Importing preliminary Libraries

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import pickle as pkl

from sklearn.datasets import make_regression, make_classification
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Testing Linear Regression Model

# %%
X, y = make_regression(n_samples=5000, n_features=200, n_informative=100, noise=0.3)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from models.Linear_Regression import LinearRegressor

linear_model = LinearRegressor(X.shape[1])
history = linear_model.train(X_train, y_train, X_test, y_test, epochs=25, lr=0.0001, log=True)
linear_model.plot_loss(history)
# Out:
# Epoch 1: 	 train_loss:  350.7321 	 val_loss:  352.9960
# Epoch 2: 	 train_loss:  230.5567 	 val_loss:  239.0611
# Epoch 3: 	 train_loss:  156.4895 	 val_loss:  166.3606
# Epoch 4: 	 train_loss:  108.9991 	 val_loss:  118.2182
# Epoch 5: 	 train_loss:  77.4616 	 val_loss:  85.3513
# Epoch 6: 	 train_loss:  55.9019 	 val_loss:  62.3711
# Epoch 7: 	 train_loss:  40.8214 	 val_loss:  46.0068
# Epoch 8: 	 train_loss:  30.0842 	 val_loss:  34.1891
# Epoch 9: 	 train_loss:  22.3337 	 val_loss:  25.5613
# Epoch 10: 	 train_loss:  16.6790 	 val_loss:  19.2076
# Epoch 11: 	 train_loss:  12.5181 	 val_loss:  14.4958
# Epoch 12: 	 train_loss:  9.4353 	 val_loss:  10.9813
# Epoch 13: 	 train_loss:  7.1384 	 val_loss:  8.3471
# Epoch 14: 	 train_loss:  5.4191 	 val_loss:  6.3647
# Epoch 15: 	 train_loss:  4.1271 	 val_loss:  4.8676
# Epoch 16: 	 train_loss:  3.1533 	 val_loss:  3.7338
# Epoch 17: 	 train_loss:  2.4177 	 val_loss:  2.8732
# Epoch 18: 	 train_loss:  1.8613 	 val_loss:  2.2191
# Epoch 19: 	 train_loss:  1.4404 	 val_loss:  1.7217
# Epoch 20: 	 train_loss:  1.1228 	 val_loss:  1.3439
# Epoch 21: 	 train_loss:  0.8841 	 val_loss:  1.0579
# Epoch 22: 	 train_loss:  0.7063 	 val_loss:  0.8428
# Epoch 23: 	 train_loss:  0.5757 	 val_loss:  0.6825
# Epoch 24: 	 train_loss:  0.4816 	 val_loss:  0.5651
# Epoch 25: 	 train_loss:  0.4156 	 val_loss:  0.4807

# %% [markdown]
# ### Testing Logistic Regression Model

# %%
X, y = make_classification(n_samples=2000, n_features=500, n_informative=200,  n_classes=2)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from models.Logistic_Regression import LogisticRegressor

model = LogisticRegressor(X.shape[1])
history = model.train(X_train, y_train, X_test, y_test, epochs=100, lr=0.001, log=True)
model.plot(history)
# Out:
# Epoch 1: 	 train_loss:  0.8528 	 val_loss:  0.8293 	 train_accuracy:  0.4879 	 val_accuracy:  0.5100
# Epoch 2: 	 train_loss:  0.8306 	 val_loss:  0.8094 	 train_accuracy:  0.4986 	 val_accuracy:  0.5250
# Epoch 3: 	 train_loss:  0.8096 	 val_loss:  0.7921 	 train_accuracy:  0.5093 	 val_accuracy:  0.5383
# Epoch 4: 	 train_loss:  0.7896 	 val_loss:  0.7760 	 train_accuracy:  0.5229 	 val_accuracy:  0.5500
# Epoch 5: 	 train_loss:  0.7705 	 val_loss:  0.7607 	 train_accuracy:  0.5364 	 val_accuracy:  0.5583
# Epoch 6: 	 train_loss:  0.7525 	 val_loss:  0.7462 	 train_accuracy:  0.5529 	 val_accuracy:  0.5633
# Epoch 7: 	 train_loss:  0.7353 	 val_loss:  0.7324 	 train_accuracy:  0.5643 	 val_accuracy:  0.5733
# Epoch 8: 	 train_loss:  0.7190 	 val_loss:  0.7193 	 train_accuracy:  0.5743 	 val_accuracy:  0.5833
# Epoch 9: 	 train_loss:  0.7035 	 val_loss:  0.7068 	 train_accuracy:  0.5814 	 val_accuracy:  0.5933
# Epoch 10: 	 train_loss:  0.6887 	 val_loss:  0.6950 	 train_accuracy:  0.5914 	 val_accuracy:  0.6017
# Epoch 11: 	 train_loss:  0.6748 	 val_loss:  0.6838 	 train_accuracy:  0.6021 	 val_accuracy:  0.6033
# Epoch 12: 	 train_loss:  0.6615 	 val_loss:  0.6732 	 train_accuracy:  0.6136 	 val_accuracy:  0.6167
# Epoch 13: 	 train_loss:  0.6489 	 val_loss:  0.6630 	 train_accuracy:  0.6329 	 val_accuracy:  0.6233
# Epoch 14: 	 train_loss:  0.6369 	 val_loss:  0.6534 	 train_accuracy:  0.6457 	 val_accuracy:  0.6300
# Epoch 15: 	 train_loss:  0.6255 	 val_loss:  0.6443 	 train_accuracy:  0.6529 	 val_accuracy:  0.6350
# Epoch 16: 	 train_loss:  0.6146 	 val_loss:  0.6356 	 train_accuracy:  0.6664 	 val_accuracy:  0.6433
# Epoch 17: 	 train_loss:  0.6043 	 val_loss:  0.6274 	 train_accuracy:  0.6736 	 val_accuracy:  0.6450
# Epoch 18: 	 train_loss:  0.5945 	 val_loss:  0.6195 	 train_accuracy:  0.6900 	 val_accuracy:  0.6500
# Epoch 19: 	 train_loss:  0.5852 	 val_loss:  0.6120 	 train_accuracy:  0.6979 	 val_accuracy:  0.6567
# Epoch 20: 	 train_loss:  0.5763 	 val_loss:  0.6049 	 train_accuracy:  0.7043 	 val_accuracy:  0.6683
# Epoch 21: 	 train_loss:  0.5678 	 val_loss:  0.5981 	 train_accuracy:  0.7171 	 val_accuracy:  0.6733
# Epoch 22: 	 train_loss:  0.5597 	 val_loss:  0.5917 	 train_accuracy:  0.7229 	 val_accuracy:  0.6817
# Epoch 23: 	 train_loss:  0.5520 	 val_loss:  0.5855 	 train_accuracy:  0.7307 	 val_accuracy:  0.6833
# Epoch 24: 	 train_loss:  0.5446 	 val_loss:  0.5796 	 train_accuracy:  0.7379 	 val_accuracy:  0.6883
# Epoch 25: 	 train_loss:  0.5376 	 val_loss:  0.5740 	 train_accuracy:  0.7457 	 val_accuracy:  0.6867
# Epoch 26: 	 train_loss:  0.5308 	 val_loss:  0.5686 	 train_accuracy:  0.7521 	 val_accuracy:  0.6933
# Epoch 27: 	 train_loss:  0.5244 	 val_loss:  0.5635 	 train_accuracy:  0.7543 	 val_accuracy:  0.7017
# Epoch 28: 	 train_loss:  0.5182 	 val_loss:  0.5586 	 train_accuracy:  0.7571 	 val_accuracy:  0.7083
# Epoch 29: 	 train_loss:  0.5123 	 val_loss:  0.5539 	 train_accuracy:  0.7629 	 val_accuracy:  0.7100
# Epoch 30: 	 train_loss:  0.5066 	 val_loss:  0.5494 	 train_accuracy:  0.7707 	 val_accuracy:  0.7100
# Epoch 31: 	 train_loss:  0.5012 	 val_loss:  0.5451 	 train_accuracy:  0.7757 	 val_accuracy:  0.7183
# Epoch 32: 	 train_loss:  0.4960 	 val_loss:  0.5409 	 train_accuracy:  0.7779 	 val_accuracy:  0.7150
# Epoch 33: 	 train_loss:  0.4909 	 val_loss:  0.5370 	 train_accuracy:  0.7836 	 val_accuracy:  0.7217
# Epoch 34: 	 train_loss:  0.4861 	 val_loss:  0.5332 	 train_accuracy:  0.7893 	 val_accuracy:  0.7217
# Epoch 35: 	 train_loss:  0.4815 	 val_loss:  0.5295 	 train_accuracy:  0.7900 	 val_accuracy:  0.7217
# Epoch 36: 	 train_loss:  0.4770 	 val_loss:  0.5260 	 train_accuracy:  0.7929 	 val_accuracy:  0.7233
# Epoch 37: 	 train_loss:  0.4727 	 val_loss:  0.5226 	 train_accuracy:  0.7971 	 val_accuracy:  0.7250
# Epoch 38: 	 train_loss:  0.4686 	 val_loss:  0.5194 	 train_accuracy:  0.8021 	 val_accuracy:  0.7333
# Epoch 39: 	 train_loss:  0.4646 	 val_loss:  0.5162 	 train_accuracy:  0.8021 	 val_accuracy:  0.7383
# Epoch 40: 	 train_loss:  0.4607 	 val_loss:  0.5132 	 train_accuracy:  0.8036 	 val_accuracy:  0.7400
# Epoch 41: 	 train_loss:  0.4570 	 val_loss:  0.5103 	 train_accuracy:  0.8079 	 val_accuracy:  0.7450
# Epoch 42: 	 train_loss:  0.4534 	 val_loss:  0.5075 	 train_accuracy:  0.8107 	 val_accuracy:  0.7483
# Epoch 43: 	 train_loss:  0.4500 	 val_loss:  0.5048 	 train_accuracy:  0.8143 	 val_accuracy:  0.7467
# Epoch 44: 	 train_loss:  0.4466 	 val_loss:  0.5022 	 train_accuracy:  0.8150 	 val_accuracy:  0.7467
# Epoch 45: 	 train_loss:  0.4434 	 val_loss:  0.4997 	 train_accuracy:  0.8164 	 val_accuracy:  0.7517
# Epoch 46: 	 train_loss:  0.4402 	 val_loss:  0.4972 	 train_accuracy:  0.8171 	 val_accuracy:  0.7517
# Epoch 47: 	 train_loss:  0.4372 	 val_loss:  0.4949 	 train_accuracy:  0.8193 	 val_accuracy:  0.7550
# Epoch 48: 	 train_loss:  0.4342 	 val_loss:  0.4926 	 train_accuracy:  0.8186 	 val_accuracy:  0.7533
# Epoch 49: 	 train_loss:  0.4313 	 val_loss:  0.4904 	 train_accuracy:  0.8179 	 val_accuracy:  0.7550
# Epoch 50: 	 train_loss:  0.4286 	 val_loss:  0.4883 	 train_accuracy:  0.8200 	 val_accuracy:  0.7567
# Epoch 51: 	 train_loss:  0.4259 	 val_loss:  0.4862 	 train_accuracy:  0.8207 	 val_accuracy:  0.7583
# Epoch 52: 	 train_loss:  0.4233 	 val_loss:  0.4842 	 train_accuracy:  0.8200 	 val_accuracy:  0.7600
# Epoch 53: 	 train_loss:  0.4207 	 val_loss:  0.4823 	 train_accuracy:  0.8250 	 val_accuracy:  0.7600
# Epoch 54: 	 train_loss:  0.4183 	 val_loss:  0.4804 	 train_accuracy:  0.8300 	 val_accuracy:  0.7600
# Epoch 55: 	 train_loss:  0.4158 	 val_loss:  0.4786 	 train_accuracy:  0.8300 	 val_accuracy:  0.7617
# Epoch 56: 	 train_loss:  0.4135 	 val_loss:  0.4768 	 train_accuracy:  0.8314 	 val_accuracy:  0.7617
# Epoch 57: 	 train_loss:  0.4112 	 val_loss:  0.4751 	 train_accuracy:  0.8336 	 val_accuracy:  0.7617
# Epoch 58: 	 train_loss:  0.4090 	 val_loss:  0.4734 	 train_accuracy:  0.8336 	 val_accuracy:  0.7633
# Epoch 59: 	 train_loss:  0.4069 	 val_loss:  0.4718 	 train_accuracy:  0.8350 	 val_accuracy:  0.7667
# Epoch 60: 	 train_loss:  0.4048 	 val_loss:  0.4702 	 train_accuracy:  0.8364 	 val_accuracy:  0.7650
# Epoch 61: 	 train_loss:  0.4027 	 val_loss:  0.4687 	 train_accuracy:  0.8386 	 val_accuracy:  0.7683
# Epoch 62: 	 train_loss:  0.4007 	 val_loss:  0.4672 	 train_accuracy:  0.8393 	 val_accuracy:  0.7700
# Epoch 63: 	 train_loss:  0.3988 	 val_loss:  0.4658 	 train_accuracy:  0.8393 	 val_accuracy:  0.7717
# Epoch 64: 	 train_loss:  0.3969 	 val_loss:  0.4643 	 train_accuracy:  0.8407 	 val_accuracy:  0.7750
# Epoch 65: 	 train_loss:  0.3950 	 val_loss:  0.4630 	 train_accuracy:  0.8414 	 val_accuracy:  0.7783
# Epoch 66: 	 train_loss:  0.3932 	 val_loss:  0.4616 	 train_accuracy:  0.8443 	 val_accuracy:  0.7783
# Epoch 67: 	 train_loss:  0.3915 	 val_loss:  0.4603 	 train_accuracy:  0.8457 	 val_accuracy:  0.7783
# Epoch 68: 	 train_loss:  0.3897 	 val_loss:  0.4591 	 train_accuracy:  0.8457 	 val_accuracy:  0.7800
# Epoch 69: 	 train_loss:  0.3881 	 val_loss:  0.4578 	 train_accuracy:  0.8464 	 val_accuracy:  0.7817
# Epoch 70: 	 train_loss:  0.3864 	 val_loss:  0.4566 	 train_accuracy:  0.8471 	 val_accuracy:  0.7817
# Epoch 71: 	 train_loss:  0.3848 	 val_loss:  0.4555 	 train_accuracy:  0.8500 	 val_accuracy:  0.7817
# Epoch 72: 	 train_loss:  0.3832 	 val_loss:  0.4543 	 train_accuracy:  0.8521 	 val_accuracy:  0.7800
# Epoch 73: 	 train_loss:  0.3817 	 val_loss:  0.4532 	 train_accuracy:  0.8543 	 val_accuracy:  0.7800
# Epoch 74: 	 train_loss:  0.3802 	 val_loss:  0.4521 	 train_accuracy:  0.8557 	 val_accuracy:  0.7783
# Epoch 75: 	 train_loss:  0.3787 	 val_loss:  0.4510 	 train_accuracy:  0.8557 	 val_accuracy:  0.7800
# Epoch 76: 	 train_loss:  0.3772 	 val_loss:  0.4500 	 train_accuracy:  0.8564 	 val_accuracy:  0.7800
# Epoch 77: 	 train_loss:  0.3758 	 val_loss:  0.4490 	 train_accuracy:  0.8571 	 val_accuracy:  0.7800
# Epoch 78: 	 train_loss:  0.3744 	 val_loss:  0.4480 	 train_accuracy:  0.8571 	 val_accuracy:  0.7783
# Epoch 79: 	 train_loss:  0.3731 	 val_loss:  0.4470 	 train_accuracy:  0.8586 	 val_accuracy:  0.7783
# Epoch 80: 	 train_loss:  0.3717 	 val_loss:  0.4461 	 train_accuracy:  0.8600 	 val_accuracy:  0.7783
# Epoch 81: 	 train_loss:  0.3704 	 val_loss:  0.4451 	 train_accuracy:  0.8614 	 val_accuracy:  0.7783
# Epoch 82: 	 train_loss:  0.3692 	 val_loss:  0.4442 	 train_accuracy:  0.8621 	 val_accuracy:  0.7783
# Epoch 83: 	 train_loss:  0.3679 	 val_loss:  0.4434 	 train_accuracy:  0.8629 	 val_accuracy:  0.7800
# Epoch 84: 	 train_loss:  0.3667 	 val_loss:  0.4425 	 train_accuracy:  0.8629 	 val_accuracy:  0.7800
# Epoch 85: 	 train_loss:  0.3655 	 val_loss:  0.4416 	 train_accuracy:  0.8643 	 val_accuracy:  0.7833
# Epoch 86: 	 train_loss:  0.3643 	 val_loss:  0.4408 	 train_accuracy:  0.8650 	 val_accuracy:  0.7850
# Epoch 87: 	 train_loss:  0.3631 	 val_loss:  0.4400 	 train_accuracy:  0.8650 	 val_accuracy:  0.7850
# Epoch 88: 	 train_loss:  0.3620 	 val_loss:  0.4392 	 train_accuracy:  0.8657 	 val_accuracy:  0.7850
# Epoch 89: 	 train_loss:  0.3608 	 val_loss:  0.4384 	 train_accuracy:  0.8664 	 val_accuracy:  0.7850
# Epoch 90: 	 train_loss:  0.3597 	 val_loss:  0.4377 	 train_accuracy:  0.8664 	 val_accuracy:  0.7867
# Epoch 91: 	 train_loss:  0.3586 	 val_loss:  0.4369 	 train_accuracy:  0.8664 	 val_accuracy:  0.7883
# Epoch 92: 	 train_loss:  0.3576 	 val_loss:  0.4362 	 train_accuracy:  0.8664 	 val_accuracy:  0.7900
# Epoch 93: 	 train_loss:  0.3565 	 val_loss:  0.4355 	 train_accuracy:  0.8686 	 val_accuracy:  0.7900
# Epoch 94: 	 train_loss:  0.3555 	 val_loss:  0.4348 	 train_accuracy:  0.8686 	 val_accuracy:  0.7900
# Epoch 95: 	 train_loss:  0.3545 	 val_loss:  0.4341 	 train_accuracy:  0.8700 	 val_accuracy:  0.7900
# Epoch 96: 	 train_loss:  0.3535 	 val_loss:  0.4334 	 train_accuracy:  0.8707 	 val_accuracy:  0.7900
# Epoch 97: 	 train_loss:  0.3525 	 val_loss:  0.4327 	 train_accuracy:  0.8714 	 val_accuracy:  0.7917
# Epoch 98: 	 train_loss:  0.3515 	 val_loss:  0.4321 	 train_accuracy:  0.8714 	 val_accuracy:  0.7933
# Epoch 99: 	 train_loss:  0.3506 	 val_loss:  0.4314 	 train_accuracy:  0.8714 	 val_accuracy:  0.7950
# Epoch 100: 	 train_loss:  0.3497 	 val_loss:  0.4308 	 train_accuracy:  0.8729 	 val_accuracy:  0.7950

# %%
X, y = make_classification(n_samples=5000, n_features=250, n_classes=2)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

print(f"Memory size of X: {sys.getsizeof(X)/(1024*1024): .3f} MB and y: {sys.getsizeof(y)/(1024*1024): .3f} MB")
# Out:
# Memory size of X:  9.537 MB and y:  0.019 MB

# %%
class Hidden_Layer_NN:
    """
    A simple neural network class for regression tasks. The neural network has multiple neurons in a single layer with linear activation.
    Supports only a single hidden layer, and the output layer has a single neuron. Classes are binary.
    
    - no_of_features (int): The number of features in the input data.
    - neurons (int): The number of neurons in the hidden layer.
    - hidden_layer_activation (str): The activation function for the hidden layer.
    - output_layer_activation (str): The activation function for the output layer.
    - w1 (ndarray): The weights of the first layer.
    - w2 (ndarray): The weights of the second layer.
    - b1 (ndarray): The bias of the first layer.
    - b2 (float): The bias of the second layer.
    
    Methods:
    - __init__(self, no_of_features, hidden_layer_activation, output_layer_activation, neurons=32): Initializes the neural network with random weights and bias.
    - rmse(self, y, y_hat): Calculates the root mean squared error (RMSE) between the predicted values and the actual values.
    - accuracy(self, y, y_hat): Calculates the accuracy of the predicted values.
    - linear(self, X): The linear activation function.
    - dlinear(self, X): The derivative of the linear activation function.
    - sigmoid(self, X): The sigmoid activation function.
    - dsigmoid(self, X): The derivative of the sigmoid activation function.
    - relu(self, X): The ReLU activation function.
    - drelu(self, X): The derivative of the ReLU activation function.
    - select_activation(self, activation): Selects the activation function based on the provided name.
    - select_derivative(self, activation): Selects the derivative of the activation function based on the provided name.
    - forward(self, X): Performs the forward pass of the neural network.
    - backward(self, X, y, y_hat, lr): Performs the backward pass of the neural network.
    - train(self, X_train, y_train, X_test, y_test, epochs=25, lr=0.0001, log=True): Trains the neural network model using the provided training data.
    - predict(self, X): Predicts the output for the given input data.
    - parameters(self): Returns the parameters of the neural network.
    - plot(self, history): Plots the training and validation loss over epochs, as well as the accuracy values.
    """
    
    def __init__(self, no_of_features: int, hidden_layer_activation: str, output_layer_activation: str, neurons: int = 32):
        self.neurons = neurons
        self.features = no_of_features
    
        self.hidden_layer_activation = hidden_layer_activation
        self.output_layer_activation = output_layer_activation
        
        self.w1 = np.random.randn(no_of_features, neurons) * np.sqrt(2. / no_of_features)
        self.w2 = np.random.randn(neurons) * np.sqrt(2. / neurons)
        self.b1 = np.zeros(neurons)
        self.b2 = 0
        
    def __repr__(self):
        return f"Hidden_Layer_NN(no_of_features={self.features}, neurons={self.neurons})"
    
    def summary(self):
        print(f"input shape: {self.features}")
        print(f"hidden layer shape: {self.neurons}")
        print(f"output shape: 1")
    
    def rmse(self, y, y_hat):
        """
        Calculates the root mean squared error (RMSE) between the predicted values (y_hat) and the actual values (y).

        Parameters:
        - y (numpy.ndarray): The actual values.
        - y_hat (numpy.ndarray): The predicted values.

        Returns:
        - float: The RMSE value.
        """
        error = np.sqrt(np.mean((y - y_hat) ** 2))
        return error
    
    def accuracy(self, y, y_hat):
        """
        Calculates the accuracy of the predicted values.

        Parameters:
        - y (numpy.ndarray): The true labels.
        - y_hat (numpy.ndarray): The predicted labels.

        Returns:
        - float: The accuracy of the predicted values.
        """
        
        y_pred = np.where(y_hat >= 0.5, 1, 0)
        accuracy  = np.mean(y == y_pred)
        return accuracy
    
    def linear(self, X):
        return X
    
    def dlinear(self, X):
        return np.ones_like(X)
    
    def sigmoid(self, X):
        return 1 / (1 + np.exp(-X))
    
    def dsigmoid(self, X):
        return self.sigmoid(X) * (1 - self.sigmoid(X))
    
    def relu(self, X):
        return np.maximum(X, 0)
    
    def drelu(self, X):
        return np.where(X > 0, 1, 0)
    
    def select_activation(self, activation: str):
        """
        Selects the activation function based on the provided name.
        
        Parameters:
        - activation (str): The name of the activation function.
        
        Returns:
        - function: The activation function.
        """
        Activators = {
            "linear": self.linear,
            "sigmoid": self.sigmoid,
            "relu": self.relu
        }
        return Activators[activation]
    
    def select_derivative(self, activation: str):
        """
        Selects the derivative of the activation function based on the provided name.
        
        Parameters:
        - activation (str): The name of the activation function.
        
        Returns:
        - function: The derivative of the activation function.
        """
        Derivatives = {
            "linear": self.dlinear,
            "sigmoid": self.dsigmoid,
            "relu": self.drelu
        }
        return Derivatives[activation]
    
    def forward(self, X):
        """
        Performs the forward pass of the neural network.

        Args:
        - X (numpy.ndarray): Input data of shape (n_samples, n_features).

        Returns:
        - numpy.ndarray: Predicted output of shape (n_samples, 1).
        """
        
        self.z1 = np.dot(X, self.w1) + self.b1
        self.a1 = self.select_activation(self.hidden_layer_activation)(self.z1)
        self.z2 = np.dot(self.a1, self.w2)
        y_hat = self.select_activation(self.output_layer_activation)(self.z2) + self.b2
        
        return y_hat
    
    def backward(self, X, y, y_hat, lr):
        """
        Performs the backward pass of the neural network.

        Args:
        - X (numpy.ndarray): Input data.
        - y (numpy.ndarray): Target labels.
        - y_hat (numpy.ndarray): Predicted labels.
        - lr (float): Learning rate.

        Returns:
        - None
        """

        loss = y_hat - y 
        w2_grad = np.dot(self.a1.T, loss * self.select_derivative(self.output_layer_activation)(self.z2))
        a1_grad = np.dot(loss.reshape(-1, 1) * self.select_derivative(self.output_layer_activation)(self.z2.reshape(-1, 1)), self.w2.reshape(-1, 1).T)
        w1_grad = np.dot(X.T, a1_grad * self.select_derivative(self.hidden_layer_activation)(self.z1))
        
        b1_grad = np.mean(a1_grad * self.select_derivative(self.hidden_layer_activation)(self.z1), axis=0)
        b2_grad = np.mean(loss * self.select_derivative(self.output_layer_activation)(self.z2))
        
        self.w2 -= lr * w2_grad
        self.w1 -= lr * w1_grad
        self.b1 -= lr * b1_grad
        self.b2 -= lr * b2_grad
        
    def train(self, X_train, y_train, X_test, y_test, epochs=25, lr=0.0001, log=True):
        """
        Trains the neural network model using the provided training data.

        Parameters:
        - X_train (numpy.ndarray): The input training data.
        - y_train (numpy.ndarray): The target training data.
        - X_test (numpy.ndarray): The input test data.
        - y_test (numpy.ndarray): The target test data.
        - epochs (int): The number of training epochs (default: 25).
        - lr (float): The learning rate for gradient descent (default: 0.0001).
        - log (bool): Whether to log the training progress (default: True).

        Returns:
        - history (dict): A dictionary containing the training history, including the loss and validation loss for each epoch.
        """
        
        print(f"Total Parameters: {self.w1.size + self.w2.size + self.b1.size + 1}")
        print(f"Size of model: {(sys.getsizeof(self.w1) + sys.getsizeof(self.w2) + sys.getsizeof(self.b1) + sys.getsizeof(self.b2))/(1024*1024): .3f} MB")
        history = {'loss': [], 'val_loss': [], 'accuracy': [], 'val_accuracy': []}

        for epoch in range(1, epochs+1):
            y_hat = self.forward(X_train)
            self.backward(X_train, y_train, y_hat, lr)
            train_pred = self.forward(X_train)
            val_pred = self.forward(X_test)

            loss = self.rmse(y_train, train_pred)
            val_loss = self.rmse(y_test, val_pred)
            accuracy = self.accuracy(y_train, train_pred)
            val_accuracy = self.accuracy(y_test, val_pred)

            history['loss'].append(loss)
            history['val_loss'].append(val_loss)
            history['accuracy'].append(accuracy)
            history['val_accuracy'].append(val_accuracy)

            if log:
                print(f"Epoch {epoch}: \t train_loss: {loss: .3f} \t val_loss: {val_loss: .3f} \t train_accuracy: {accuracy: .3f} \t val_accuracy: {val_accuracy: .3f}")

        return history
    
    def predict(self, X):
        """
        Predicts the output for the given input data.

        Parameters:
        - X (numpy.ndarray): The input data to be predicted.

        Returns:
        - numpy.ndarray: The predicted output for the input data.
        """
        try:
            return self.forward(X)
        except Exception as e:
            print(f"An error occurred: {e}")
            
    def parameters(self):
        """
        Returns the parameters of the neural network.

        Returns:
            dict: A dictionary containing the weights and bias of the neural network.
                - "weights1" (ndarray): The weights of the first layer.
                - "weights2" (ndarray): The weights of the second layer.
                - "bias" (ndarray): The bias of the neural network.
        """
        
        return {"weights": [self.w1, self.w2], "bias": [self.b1, self.b2]}
    
    def save_weights(self, path):
        """
        Saves the weights and bias of the neural network to a file.

        Parameters:
        - path (str): The path to save the weights and bias.

        Returns:
        - None
        """
        
        np.savez(path, w1=self.w1, w2=self.w2, b1=self.b1, b2=self.b2)
        
    def save_model(self, path):
        """
        Saves the model to a file.

        Parameters:
        - path (str): The path to save the model.

        Returns:
        - None
        """
        import pickle
        
        with open(path, 'wb') as f:
            pickle.dump(self, f)
            
    def load_weights(self, path):
        """
        Loads the weights and bias of the neural network from a file.

        Parameters:
        - path (str): The path to load the weights and bias.

        Returns:
        - None
        """
        
        data = np.load(path)
        self.w1 = data['w1']
        self.w2 = data['w2']
        self.b1 = data['b1']
        self.b2 = data['b2']
            
    def plot(self, history):
        """
        Plots the training and validation loss over epochs.

        Parameters:
        - history (dict): A dictionary containing the training and validation loss values, as well as the accuracy values.

        Returns:
        - None
        """

        plt.figure(figsize=(16, 8))

        plt.subplot(2, 2, 1)
        plt.plot(history['loss'], label='train_loss', color='blue', lw=0.8)
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title('Training')
        plt.grid(True)

        plt.subplot(2, 2, 2)
        plt.plot(history['val_loss'], label='val_loss', color='red', lw=0.8)
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title('Validation')
        plt.grid(True)
        
        plt.subplot(2, 2, 3)
        plt.plot(history['accuracy'], label='train_accuracy', color='blue', lw=0.8) 
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.title('Training')
        plt.grid(True)
        
        plt.subplot(2, 2, 4)
        plt.plot(history['val_accuracy'], label='val_accuracy', color='red', lw=0.8)
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.title('Validation')
        plt.grid(True)
        
        plt.tight_layout()
        plt.show()
        
model = Hidden_Layer_NN(no_of_features=X.shape[1], neurons=64, hidden_layer_activation="relu", output_layer_activation="sigmoid")
history = model.train(X_train, y_train, X_test, y_test, epochs=100, lr=0.0001, log=True)
model.plot(history)
# Out:
# Total Parameters: 32129
# Size of model:  0.245 MB
# Epoch 1: 	 train_loss:  0.633 	 val_loss:  0.623 	 train_accuracy:  0.541 	 val_accuracy:  0.562
# Epoch 2: 	 train_loss:  0.619 	 val_loss:  0.615 	 train_accuracy:  0.560 	 val_accuracy:  0.570
# Epoch 3: 	 train_loss:  0.606 	 val_loss:  0.611 	 train_accuracy:  0.586 	 val_accuracy:  0.575
# Epoch 4: 	 train_loss:  0.594 	 val_loss:  0.606 	 train_accuracy:  0.606 	 val_accuracy:  0.582
# Epoch 5: 	 train_loss:  0.584 	 val_loss:  0.603 	 train_accuracy:  0.624 	 val_accuracy:  0.580
# Epoch 6: 	 train_loss:  0.574 	 val_loss:  0.597 	 train_accuracy:  0.636 	 val_accuracy:  0.592
# Epoch 7: 	 train_loss:  0.566 	 val_loss:  0.599 	 train_accuracy:  0.644 	 val_accuracy:  0.590
# Epoch 8: 	 train_loss:  0.560 	 val_loss:  0.588 	 train_accuracy:  0.644 	 val_accuracy:  0.607
# Epoch 9: 	 train_loss:  0.558 	 val_loss:  0.597 	 train_accuracy:  0.646 	 val_accuracy:  0.575
# Epoch 10: 	 train_loss:  0.557 	 val_loss:  0.582 	 train_accuracy:  0.646 	 val_accuracy:  0.615
# Epoch 11: 	 train_loss:  0.545 	 val_loss:  0.591 	 train_accuracy:  0.664 	 val_accuracy:  0.590
# Epoch 12: 	 train_loss:  0.539 	 val_loss:  0.574 	 train_accuracy:  0.670 	 val_accuracy:  0.613
# Epoch 13: 	 train_loss:  0.526 	 val_loss:  0.585 	 train_accuracy:  0.693 	 val_accuracy:  0.600
# Epoch 14: 	 train_loss:  0.518 	 val_loss:  0.564 	 train_accuracy:  0.701 	 val_accuracy:  0.625
# Epoch 15: 	 train_loss:  0.503 	 val_loss:  0.572 	 train_accuracy:  0.728 	 val_accuracy:  0.623
# Epoch 16: 	 train_loss:  0.498 	 val_loss:  0.560 	 train_accuracy:  0.732 	 val_accuracy:  0.623
# Epoch 17: 	 train_loss:  0.490 	 val_loss:  0.565 	 train_accuracy:  0.745 	 val_accuracy:  0.625
# Epoch 18: 	 train_loss:  0.485 	 val_loss:  0.555 	 train_accuracy:  0.749 	 val_accuracy:  0.633
# Epoch 19: 	 train_loss:  0.479 	 val_loss:  0.560 	 train_accuracy:  0.761 	 val_accuracy:  0.635
# Epoch 20: 	 train_loss:  0.477 	 val_loss:  0.549 	 train_accuracy:  0.754 	 val_accuracy:  0.638
# Epoch 21: 	 train_loss:  0.470 	 val_loss:  0.553 	 train_accuracy:  0.764 	 val_accuracy:  0.632
# Epoch 22: 	 train_loss:  0.470 	 val_loss:  0.545 	 train_accuracy:  0.760 	 val_accuracy:  0.645
# Epoch 23: 	 train_loss:  0.464 	 val_loss:  0.546 	 train_accuracy:  0.772 	 val_accuracy:  0.642
# Epoch 24: 	 train_loss:  0.465 	 val_loss:  0.543 	 train_accuracy:  0.764 	 val_accuracy:  0.652
