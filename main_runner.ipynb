# %% [markdown]
# ### Importing preliminary Libraries

# %%
from sklearn.datasets import make_regression, make_classification
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Testing Linear Regression Model

# %%
X, y = make_regression(n_samples=5000, n_features=200, n_informative=100, noise=0.3)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from models.Linear_Regression import LinearRegressor

linear_model = LinearRegressor(X.shape[1])
history = linear_model.train(X_train, y_train, X_test, y_test, epochs=25, lr=0.0001, log=True)
linear_model.plot(history)
# Out:
# Epoch 1: 	 train_loss:  368.5498 	 val_loss:  383.8411
# Epoch 2: 	 train_loss:  244.8980 	 val_loss:  262.9116
# Epoch 3: 	 train_loss:  167.2907 	 val_loss:  184.2743
# Epoch 4: 	 train_loss:  116.8708 	 val_loss:  131.5170
# Epoch 5: 	 train_loss:  83.1301 	 val_loss:  95.2130
# Epoch 6: 	 train_loss:  59.9904 	 val_loss:  69.7195
# Epoch 7: 	 train_loss:  43.8005 	 val_loss:  51.5256
# Epoch 8: 	 train_loss:  32.2876 	 val_loss:  38.3712
# Epoch 9: 	 train_loss:  23.9912 	 val_loss:  28.7592
# Epoch 10: 	 train_loss:  17.9470 	 val_loss:  21.6738
# Epoch 11: 	 train_loss:  13.5033 	 val_loss:  16.4123
# Epoch 12: 	 train_loss:  10.2111 	 val_loss:  12.4806
# Epoch 13: 	 train_loss:  7.7560 	 val_loss:  9.5267
# Epoch 14: 	 train_loss:  5.9150 	 val_loss:  7.2972
# Epoch 15: 	 train_loss:  4.5279 	 val_loss:  5.6076
# Epoch 16: 	 train_loss:  3.4787 	 val_loss:  4.3227
# Epoch 17: 	 train_loss:  2.6825 	 val_loss:  3.3429
# Epoch 18: 	 train_loss:  2.0770 	 val_loss:  2.5940
# ...

# %% [markdown]
# ### Testing Logistic Regression Model

# %%
X, y = make_classification(n_samples=2000, n_features=500, n_informative=200,  n_classes=2)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from models.Logistic_Regression import LogisticRegressor

model = LogisticRegressor(X.shape[1])
history = model.train(X_train, y_train, X_test, y_test, epochs=100, lr=0.001, log=True)
model.plot(history)
# Out:
# Epoch 1: 	 train_loss:  0.8347 	 val_loss:  0.8001 	 train_accuracy:  0.4986 	 val_accuracy:  0.5267
# Epoch 2: 	 train_loss:  0.8087 	 val_loss:  0.7847 	 train_accuracy:  0.4964 	 val_accuracy:  0.5333
# Epoch 3: 	 train_loss:  0.7913 	 val_loss:  0.7717 	 train_accuracy:  0.5114 	 val_accuracy:  0.5367
# Epoch 4: 	 train_loss:  0.7748 	 val_loss:  0.7586 	 train_accuracy:  0.5200 	 val_accuracy:  0.5417
# Epoch 5: 	 train_loss:  0.7591 	 val_loss:  0.7460 	 train_accuracy:  0.5279 	 val_accuracy:  0.5500
# Epoch 6: 	 train_loss:  0.7441 	 val_loss:  0.7340 	 train_accuracy:  0.5436 	 val_accuracy:  0.5650
# Epoch 7: 	 train_loss:  0.7299 	 val_loss:  0.7226 	 train_accuracy:  0.5536 	 val_accuracy:  0.5650
# Epoch 8: 	 train_loss:  0.7163 	 val_loss:  0.7118 	 train_accuracy:  0.5621 	 val_accuracy:  0.5700
# Epoch 9: 	 train_loss:  0.7033 	 val_loss:  0.7015 	 train_accuracy:  0.5707 	 val_accuracy:  0.5817
# ...

# %% [markdown]
# ### Testing Neural Network

# %%
X, y = make_classification(n_samples=5000, n_features=500, n_classes=2)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from models.Neural_Network import Single_Layer_NN

model = Single_Layer_NN(no_of_features=X.shape[1], neurons=128, hidden_layer_activation="relu", output_layer_activation="sigmoid")
history = model.train(X_train, y_train, X_test, y_test, epochs=25, lr=0.001, log=True)
model.plot(history)
# Out:
# Total Parameters: 64257
# Size of model:  0.491 MB
# Epoch 1: 	 train_loss:  0.498 	 val_loss:  0.499 	 train_accuracy:  0.614 	 val_accuracy:  0.591
# Epoch 2: 	 train_loss:  0.496 	 val_loss:  0.497 	 train_accuracy:  0.675 	 val_accuracy:  0.647
# Epoch 3: 	 train_loss:  0.493 	 val_loss:  0.494 	 train_accuracy:  0.737 	 val_accuracy:  0.695
# Epoch 4: 	 train_loss:  0.488 	 val_loss:  0.489 	 train_accuracy:  0.793 	 val_accuracy:  0.749
# Epoch 5: 	 train_loss:  0.478 	 val_loss:  0.481 	 train_accuracy:  0.840 	 val_accuracy:  0.801
# Epoch 6: 	 train_loss:  0.462 	 val_loss:  0.468 	 train_accuracy:  0.874 	 val_accuracy:  0.827
# Epoch 7: 	 train_loss:  0.438 	 val_loss:  0.447 	 train_accuracy:  0.899 	 val_accuracy:  0.851
# Epoch 8: 	 train_loss:  0.406 	 val_loss:  0.420 	 train_accuracy:  0.911 	 val_accuracy:  0.869
# Epoch 9: 	 train_loss:  0.370 	 val_loss:  0.391 	 train_accuracy:  0.918 	 val_accuracy:  0.875
# ...
